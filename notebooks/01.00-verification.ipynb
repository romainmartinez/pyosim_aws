# %% [markdown]
# <!--BOOK_INFORMATION-->
# <img style="float: right; width: 100px" src="https://raw.github.com/pyomeca/design/master/logo/logo_cropped.svg?sanitize=true">
#
# <font size="+2">Pyosim in the cloud</font>
#
# <font size="+1">with [pyomeca](https://github.com/pyomeca/pyom</font>a)
#
# Romain Martinez (martinez.staps@gmail.com | [GitHub](https://github.com/romainmartinez))

# %% [markdown]
# <!--NAVIGATION-->
# < [Logistics](00.00-logistics.ipynb) | [Contents](Index.ipynb) | [Inverse kinematics](01.01-inverse-kinematics.ipynb) >

# %% [markdown]
# # Verification

# %%
from pathlib import Path

import yaml
import numpy as np
import pandas as pd
import altair as alt
from pyosim import Conf
from pyomeca import Analogs3d

from src.util import parse_conditions

# %%
aws_conf = yaml.safe_load(open("../conf.yml"))

conf = Conf(project_path=aws_conf["path"]["project"]["local"])
conf.check_confs()
# Out:
# Project loaded
# Configuration file loaded

# %% [markdown]
# ## Project cleaner

# %%
def clean_project_dir(project, query, contains=None):
    for ifile in project.glob(query):
        if contains:
            if contains not in ifile.stem:
                print(ifile.stem)
                ifile.unlink()
        else:
            print(ifile.stem)
            ifile.unlink()

# %%
clean_project_dir(
    project=conf.project_path, query="*/5_joint_reaction_force/*"
)
# Out:
# wu_VerCF6H2_1_JointReaction_ReactionLoads
# wu_VerCF12H2_2_JointReaction_ReactionLoads
# wu_VerCF6H2_3_JointReaction_ReactionLoads
# wu_VerCF12H2_1_JointReaction_ReactionLoads
# wu_VerCF6H2_2_JointReaction_ReactionLoads
# wu_VerCF12H2_3_JointReaction_ReactionLoads
# wu_JawRH6H2_3_JointReaction_ReactionLoads
# wu_JawRH18H2_2_JointReaction_ReactionLoads
# wu_JawRH6H2_1_JointReaction_ReactionLoads
# wu_JawRH18H2_1_JointReaction_ReactionLoads
# wu_JawRH6H2_2_JointReaction_ReactionLoads
# wu_JawRH12H2_2_JointReaction_ReactionLoads
# wu_JawRH12H2_3_JointReaction_ReactionLoads
# wu_JawRH18H2_3_JointReaction_ReactionLoads
# wu_GabFH18H2_1_JointReaction_ReactionLoads
# wu_GabFH12H2_2_JointReaction_ReactionLoads
# wu_GabFH18H2_2_JointReaction_ReactionLoads
# wu_GabFH6H2_3_JointReaction_ReactionLoads
# wu_GabFH6H2_2_JointReaction_ReactionLoads
# wu_GabFH6H2_1_JointReaction_ReactionLoads
# wu_GabFH12H2_1_JointReaction_ReactionLoads
# wu_GabFH12H2_3_JointReaction_ReactionLoads
# wu_GabFH18H2_3_JointReaction_ReactionLoads
# wu_AleBH6H2_1_JointReaction_ReactionLoads
# wu_AleBH12H2_2_JointReaction_ReactionLoads
# wu_AleBH6H2_3_JointReaction_ReactionLoads
# wu_AleBH18H2_2_JointReaction_ReactionLoads
# wu_AleBH12H2_1_JointReaction_ReactionLoads
# wu_AleBH6H2_2_JointReaction_ReactionLoads
# wu_AleBH18H2_1_JointReaction_ReactionLoads
# wu_AleBH12H2_3_JointReaction_ReactionLoads
# wu_AleBH18H2_3_JointReaction_ReactionLoads
# wu_DocAH12H2_2_JointReaction_ReactionLoads
# wu_DocAH18H2_3_JointReaction_ReactionLoads
# wu_DocAH6H2_2_JointReaction_ReactionLoads
# wu_DocAH18H2_2_JointReaction_ReactionLoads
# wu_DocAH6H2_3_JointReaction_ReactionLoads
# wu_DocAH18H2_1_JointReaction_ReactionLoads
# wu_DocAH12H2_3_JointReaction_ReactionLoads
# wu_DocAH6H2_1_JointReaction_ReactionLoads
# wu_DocAH12H2_1_JointReaction_ReactionLoads
# wu_AmiAF6H2_3_JointReaction_ReactionLoads
# wu_AmiAF12H2_2_JointReaction_ReactionLoads
# wu_AmiAF12H2_3_JointReaction_ReactionLoads
# wu_AmiAF12H2_1_JointReaction_ReactionLoads
# wu_AmiAF6H2_1_JointReaction_ReactionLoads
# wu_AmiAF6H2_2_JointReaction_ReactionLoads
# wu_EveDF6H2_1_JointReaction_ReactionLoads
# wu_EveDF12H2_3_JointReaction_ReactionLoads
# wu_EveDF12H2_2_JointReaction_ReactionLoads
# wu_EveDF6H2_3_JointReaction_ReactionLoads
# wu_EveDF12H2_1_JointReaction_ReactionLoads
# wu_EveDF6H2_2_JointReaction_ReactionLoads
# wu_AleFF6H2_3_JointReaction_ReactionLoads
# wu_AleFF12H2_3_JointReaction_ReactionLoads
# wu_AleFF6H2_2_JointReaction_ReactionLoads
# wu_AleFF6H2_1_JointReaction_ReactionLoads
# wu_AleFF12H2_1_JointReaction_ReactionLoads
# wu_AleFF12H2_2_JointReaction_ReactionLoads
# wu_RomMH12H2_1_JointReaction_ReactionLoads
# wu_RomMH12H2_2_JointReaction_ReactionLoads
# wu_RomMH6H2_3_JointReaction_ReactionLoads
# wu_RomMH12H2_3_JointReaction_ReactionLoads
# wu_RomMH6H2_2_JointReaction_ReactionLoads
# wu_RomMH18H2_3_JointReaction_ReactionLoads
# wu_RomMH18H2_2_JointReaction_ReactionLoads
# wu_RomMH18H2_1_JointReaction_ReactionLoads
# wu_RomMH6H2_1_JointReaction_ReactionLoads
# wu_DapOF12H2_3_JointReaction_ReactionLoads
# wu_DapOF6H2_3_JointReaction_ReactionLoads
# wu_DapOF12H2_2_JointReaction_ReactionLoads
# wu_DapOF6H2_2_JointReaction_ReactionLoads
# wu_DapOF6H2_1_JointReaction_ReactionLoads
# wu_DapOF12H2_1_JointReaction_ReactionLoads
# wu_NoeLF6H2_1_JointReaction_ReactionLoads
# wu_NoeLF12H2_2_JointReaction_ReactionLoads
# wu_NoeLF6H2_3_JointReaction_ReactionLoads
# wu_NoeLF12H2_3_JointReaction_ReactionLoads
# wu_NoeLF6H2_2_JointReaction_ReactionLoads
# wu_SarCF12H2_2_JointReaction_ReactionLoads
# wu_SarCF6H2_3_JointReaction_ReactionLoads
# wu_SarCF6H2_1_JointReaction_ReactionLoads
# wu_SarCF12H2_1_JointReaction_ReactionLoads
# wu_SarCF12H2_3_JointReaction_ReactionLoads
# wu_SarCF6H2_2_JointReaction_ReactionLoads
# wu_RoxDF12H2_1_JointReaction_ReactionLoads
# wu_RoxDF6H2_3_JointReaction_ReactionLoads
# wu_RoxDF12H2_3_JointReaction_ReactionLoads
# wu_RoxDF12H2_2_JointReaction_ReactionLoads
# wu_RoxDF6H2_1_JointReaction_ReactionLoads
# wu_RoxDF6H2_2_JointReaction_ReactionLoads
# wu_AimQF12H2_1_JointReaction_ReactionLoads
# wu_AimQF6H2_3_JointReaction_ReactionLoads
# wu_AimQF12H2_2_JointReaction_ReactionLoads
# wu_AimQF12H2_3_JointReaction_ReactionLoads
# wu_AimQF6H2_1_JointReaction_ReactionLoads
# wu_AimQF6H2_2_JointReaction_ReactionLoads
# wu_AnnSF12H2_2_JointReaction_ReactionLoads
# wu_AnnSF6H2_2_JointReaction_ReactionLoads
# wu_AnnSF12H2_3_JointReaction_ReactionLoads
# wu_AnnSF12H2_1_JointReaction_ReactionLoads
# wu_MarMH12H2_3_JointReaction_ReactionLoads
# wu_MarMH18H2_2_JointReaction_ReactionLoads
# wu_MarMH18H2_3_JointReaction_ReactionLoads
# wu_MarMH18H2_1_JointReaction_ReactionLoads
# wu_MarMH12H2_1_JointReaction_ReactionLoads
# wu_MarMH12H2_2_JointReaction_ReactionLoads
# wu_MarMH6H2_1_JointReaction_ReactionLoads
# wu_MarMH6H2_3_JointReaction_ReactionLoads
# wu_MarMH6H2_2_JointReaction_ReactionLoads
# wu_GeoAH18H2_1_JointReaction_ReactionLoads
# wu_GeoAH6H2_2_JointReaction_ReactionLoads
# wu_GeoAH6H2_3_JointReaction_ReactionLoads
# wu_GeoAH12H2_1_JointReaction_ReactionLoads
# wu_GeoAH12H2_3_JointReaction_ReactionLoads
# wu_GeoAH6H2_1_JointReaction_ReactionLoads
# wu_GeoAH12H2_2_JointReaction_ReactionLoads
# wu_GeoAH18H2_2_JointReaction_ReactionLoads
# wu_CamBF6H2_1_JointReaction_ReactionLoads
# wu_CamBF12H2_1_JointReaction_ReactionLoads
# wu_CamBF6H2_3_JointReaction_ReactionLoads
# wu_CamBF12H2_3_JointReaction_ReactionLoads
# wu_CamBF6H2_2_JointReaction_ReactionLoads
# wu_CamBF12H2_2_JointReaction_ReactionLoads
# wu_KarMH6H2_1_JointReaction_ReactionLoads
# wu_KarMH18H2_3_JointReaction_ReactionLoads
# wu_KarMH6H2_2_JointReaction_ReactionLoads
# wu_KarMH18H2_1_JointReaction_ReactionLoads
# wu_KarMH18H2_2_JointReaction_ReactionLoads
# wu_KarMH12H2_2_JointReaction_ReactionLoads
# wu_KarMH12H2_1_JointReaction_ReactionLoads
# wu_KarMH6H2_3_JointReaction_ReactionLoads
# wu_KarMH12H2_3_JointReaction_ReactionLoads
# wu_SylGM18H2_1_JointReaction_ReactionLoads
# wu_SylGM18H2_2_JointReaction_ReactionLoads
# wu_SylGM18H2_3_JointReaction_ReactionLoads
# wu_SylGM12H2_3_JointReaction_ReactionLoads
# wu_SylGM12H2_1_JointReaction_ReactionLoads
# wu_SylGM12H2_2_JointReaction_ReactionLoads
# wu_SylGM6H2_3_JointReaction_ReactionLoads
# wu_SylGM6H2_1_JointReaction_ReactionLoads
# wu_SylGM6H2_2_JointReaction_ReactionLoads
# wu_LauGF6H2_1_JointReaction_ReactionLoads
# wu_LauGF12H2_2_JointReaction_ReactionLoads
# wu_LauGF6H2_3_JointReaction_ReactionLoads
# wu_LauGF12H2_3_JointReaction_ReactionLoads
# wu_LauGF6H2_2_JointReaction_ReactionLoads
# wu_LauGF12H2_1_JointReaction_ReactionLoads
# wu_MarSF12H2_2_JointReaction_ReactionLoads
# wu_MarSF6H2_1_JointReaction_ReactionLoads
# wu_MarSF12H2_3_JointReaction_ReactionLoads
# wu_MarSF6H2_3_JointReaction_ReactionLoads
# wu_MarSF6H2_2_JointReaction_ReactionLoads
# wu_MarSF12H2_1_JointReaction_ReactionLoads
# wu_SteBF6H2_3_JointReaction_ReactionLoads
# wu_SteBF12H2_3_JointReaction_ReactionLoads
# wu_SteBF6H2_1_JointReaction_ReactionLoads
# wu_SteBF12H2_1_JointReaction_ReactionLoads
# wu_SteBF12H2_2_JointReaction_ReactionLoads
# wu_DamGH6H2_1_JointReaction_ReactionLoads
# wu_DamGH6H2_2_JointReaction_ReactionLoads
# wu_DamGH18H2_3_JointReaction_ReactionLoads
# wu_DamGH18H2_2_JointReaction_ReactionLoads
# wu_DamGH12H2_2_JointReaction_ReactionLoads
# wu_DamGH18H2_1_JointReaction_ReactionLoads
# wu_DamGH12H2_3_JointReaction_ReactionLoads
# wu_DamGH12H2_1_JointReaction_ReactionLoads
# wu_DamGH6H2_3_JointReaction_ReactionLoads
# wu_MarHF6H2_1_JointReaction_ReactionLoads
# wu_MarHF12H2_3_JointReaction_ReactionLoads
# wu_MarHF6H2_3_JointReaction_ReactionLoads
# wu_MarHF12H2_1_JointReaction_ReactionLoads
# wu_MarHF12H2_2_JointReaction_ReactionLoads
# wu_MarHF6H2_2_JointReaction_ReactionLoads
# wu_AmeGF6H2_1_JointReaction_ReactionLoads
# wu_AmeGF12H2_2_JointReaction_ReactionLoads
# wu_AmeGF12H2_3_JointReaction_ReactionLoads
# wu_AmeGF6H2_2_JointReaction_ReactionLoads
# wu_AmeGF12H2_1_JointReaction_ReactionLoads
# wu_AmeGF6H2_3_JointReaction_ReactionLoads
# wu_IneAF12H2_1_JointReaction_ReactionLoads
# wu_IneAF6H2_3_JointReaction_ReactionLoads
# wu_IneAF12H2_3_JointReaction_ReactionLoads
# wu_IneAF12H2_2_JointReaction_ReactionLoads
# wu_IneAF6H2_1_JointReaction_ReactionLoads
# wu_IneAF6H2_2_JointReaction_ReactionLoads
# wu_ArsTH12H2_1_JointReaction_ReactionLoads
# wu_ArsTH18H2_2_JointReaction_ReactionLoads
# wu_ArsTH18H2_3_JointReaction_ReactionLoads
# wu_ArsTH12H2_2_JointReaction_ReactionLoads
# wu_ArsTH6H2_2_JointReaction_ReactionLoads
# wu_ArsTH6H2_3_JointReaction_ReactionLoads
# wu_ArsTH6H2_1_JointReaction_ReactionLoads
# wu_ArsTH12H2_3_JointReaction_ReactionLoads
# wu_ArsTH18H2_1_JointReaction_ReactionLoads
# wu_NemKH12H2_3_JointReaction_ReactionLoads
# wu_NemKH12H2_1_JointReaction_ReactionLoads
# wu_NemKH6H2_1_JointReaction_ReactionLoads
# wu_NemKH18H2_2_JointReaction_ReactionLoads
# wu_NemKH18H2_1_JointReaction_ReactionLoads
# wu_NemKH6H2_2_JointReaction_ReactionLoads
# wu_FabDH12H2_2_JointReaction_ReactionLoads
# wu_FabDH6H2_1_JointReaction_ReactionLoads
# wu_FabDH18H2_2_JointReaction_ReactionLoads
# wu_FabDH18H2_1_JointReaction_ReactionLoads
# wu_FabDH12H2_1_JointReaction_ReactionLoads
# wu_FabDH18H2_3_JointReaction_ReactionLoads
# wu_FabDH6H2_2_JointReaction_ReactionLoads
# wu_FabDH6H2_3_JointReaction_ReactionLoads
# wu_FabDH12H2_3_JointReaction_ReactionLoads
# wu_YoaBH18H2_1_JointReaction_ReactionLoads
# wu_YoaBH6H2_3_JointReaction_ReactionLoads
# wu_YoaBH6H2_1_JointReaction_ReactionLoads
# wu_YoaBH12H2_2_JointReaction_ReactionLoads
# wu_YoaBH18H2_2_JointReaction_ReactionLoads
# wu_YoaBH12H2_3_JointReaction_ReactionLoads
# wu_YoaBH6H2_2_JointReaction_ReactionLoads
# wu_YoaBH12H2_1_JointReaction_ReactionLoads
# wu_YoaBH18H2_3_JointReaction_ReactionLoads
# wu_PhiIH6H2_1_JointReaction_ReactionLoads
# wu_PhiIH18H2_1_JointReaction_ReactionLoads
# wu_PhiIH12H2_3_JointReaction_ReactionLoads
# wu_PhiIH12H2_1_JointReaction_ReactionLoads
# wu_PhiIH6H2_2_JointReaction_ReactionLoads
# wu_NauSF6H2_1_JointReaction_ReactionLoads
# wu_NauSF6H2_3_JointReaction_ReactionLoads
# wu_NauSF12H2_1_JointReaction_ReactionLoads
# wu_NauSF12H2_2_JointReaction_ReactionLoads
# wu_NauSF6H2_2_JointReaction_ReactionLoads
# wu_NauSF12H2_3_JointReaction_ReactionLoads
# wu_SamNF12H2_2_JointReaction_ReactionLoads
# wu_SamNF12H2_1_JointReaction_ReactionLoads
# wu_SamNF6H2_2_JointReaction_ReactionLoads
# wu_SamNF6H2_1_JointReaction_ReactionLoads
# wu_SamNF12H2_3_JointReaction_ReactionLoads
# wu_SamNF6H2_3_JointReaction_ReactionLoads
# wu_YoaPH6H2_1_JointReaction_ReactionLoads
# wu_YoaPH18H2_3_JointReaction_ReactionLoads
# wu_YoaPH12H2_3_JointReaction_ReactionLoads
# wu_YoaPH12H2_1_JointReaction_ReactionLoads
# wu_YoaPH6H2_3_JointReaction_ReactionLoads
# wu_YoaPH18H2_2_JointReaction_ReactionLoads
# wu_YoaPH18H2_1_JointReaction_ReactionLoads
# wu_YoaPH6H2_2_JointReaction_ReactionLoads
# wu_MatRH18H2_3_JointReaction_ReactionLoads
# wu_MatRH6H2_3_JointReaction_ReactionLoads
# wu_MatRH6H2_1_JointReaction_ReactionLoads
# wu_MatRH12H2_1_JointReaction_ReactionLoads
# wu_MatRH12H2_3_JointReaction_ReactionLoads
# wu_MatRH18H2_1_JointReaction_ReactionLoads
# wu_MatRH6H2_2_JointReaction_ReactionLoads
# wu_MatRH12H2_2_JointReaction_ReactionLoads
# wu_MatRH18H2_2_JointReaction_ReactionLoads
# wu_DavOH6H2_3_JointReaction_ReactionLoads
# wu_DavOH12H2_1_JointReaction_ReactionLoads
# wu_DavOH18H2_3_JointReaction_ReactionLoads
# wu_DavOH6H2_2_JointReaction_ReactionLoads
# wu_DavOH12H2_2_JointReaction_ReactionLoads
# wu_DavOH18H2_1_JointReaction_ReactionLoads
# wu_DavOH6H2_1_JointReaction_ReactionLoads
# wu_DavOH18H2_2_JointReaction_ReactionLoads

# %%
# clean_project_dir(project=conf.project_path, query="*/3_static_optimization/*")

# %% [markdown]
# ## Condition counter

# %%
PROJECT = Path("/home/romain/Downloads/irsst/")
MODEL = "wu_"
EXT = ".mot"

# %%
verif.head()
# Out:
#       filename               trial  tag  note participant sex height weight  \
# 0   VerCF6H2_2   wu_VerCF6H2_2.mot    1   NaN        wu_v   e      m   rCF6
# 1  VerCF12H2_3  wu_VerCF12H2_3.mot    1   NaN        wu_v   e      m  rCF12
# 2   VerCF6H2_1   wu_VerCF6H2_1.mot    1   NaN        wu_v   e      m   rCF6
# 3  VerCF12H2_2  wu_VerCF12H2_2.mot    1   NaN        wu_v   e      m  rCF12
# 4   VerCF6H2_3   wu_VerCF6H2_3.mot    1   NaN        wu_v   e      m   rCF6
#
#   n_trial
# 0       t
# 1       t
# 2       t
# 3       t
# 4       t

# %% [markdown]
# <!--NAVIGATION-->
# < [Logistics](00.00-logistics.ipynb) | [Contents](Index.ipynb) | [Inverse kinematics](01.01-inverse-kinematics.ipynb) >
